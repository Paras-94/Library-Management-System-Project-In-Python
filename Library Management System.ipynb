# %% [markdown]
# Library Management System

# %%
#Library Management system
class book:
  def __init__(self,t,a,c):
    self.title=t
    self.author=a
    self.cost=c
  def Return(self):
    return exit()
list_of_book=[]
while 1:
  print("******Library Management System***********************")
  print("Press 1 to add new book")
  print("Press 2 to Delete book")
  print("Press 3 to show all books")
  print("press 4 to add new Student")
  print("press 5 to Delete Student")
  print("Press 6 to issue book")
  print("Press 7 to Return book")
list_of_books=[]
str=input("chose option:")
if str=='1':
  t=input("Enter the title")
  a=input("Enter the name of author:")
  c=input("Enter the cost of the book:")
  list_of_book.append(book(t,a,c))
  print("successfully added")
elif str=='3':
  for i in list_of_books:
    print("Book Title:",i.title)
    print("Author:",i.author)
    print("cost:",i.cost)
elif str=='8':
    print("Thank you for visiting this site")
break
# Out:
# Streaming output truncated to the last 5000 lines.
# press 5 to Delete Student
# Press 6 to issue book
# Press 7 to Return book
# ******Library Management System***********************
# Press 1 to add new book
# Press 2 to Delete book
# Press 3 to show all books
# press 4 to add new Student
# press 5 to Delete Student
# Press 6 to issue book
# Press 7 to Return book
# ******Library Management System***********************
# Press 1 to add new book
# Press 2 to Delete book
# Press 3 to show all books
# press 4 to add new Student
# press 5 to Delete Student
# Press 6 to issue book
# Press 7 to Return book
# ******Library Management System***********************
# Press 1 to add new book
# Press 2 to Delete book
# Press 3 to show all books
# press 4 to add new Student
# press 5 to Delete Student
# Press 6 to issue book
# Press 7 to Return book
# ******Library Management System***********************
# Press 1 to add new book
# Press 2 to Delete book
# Press 3 to show all books
# ...
